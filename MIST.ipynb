# %%
# %matplotlib inline
import read_mist_models
import numpy as np
import matplotlib.pyplot as plt
from HeaderP import *

# %%
iso = read_mist_models.ISO('feh0_iso.iso')
iso_2 = read_mist_models.ISO('fehm1_iso.iso')
# Out:
# Reading in: feh0_iso.iso
# Reading in: fehm1_iso.iso

# %%
for i in range(len(iso.isos)):
    logTeff = iso.isos[i]['log_Teff']
    logL = iso.isos[i]['log_L']
    if i==0:
        plt.plot(logTeff, logL, 'k', label='[Fe/H] = 0') 
    else:
        plt.plot(logTeff, logL, 'k') 
    
for i in range(len(iso_2.isos)):
    logTeff = iso_2.isos[i]['log_Teff']
    logL = iso_2.isos[i]['log_L']
    if i==0:
        plt.plot(logTeff, logL, 'r', label= '[Fe/H] = -1') 
    else:The 
        plt.plot(logTeff, logL, 'r') 
    plt.xlabel('log(Teff)')
    plt.ylabel('log(L)')
    plt.axis([4, 3.3, -4, 5])
    
plt.legend()
